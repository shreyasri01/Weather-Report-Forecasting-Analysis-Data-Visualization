# %%
# !pip install mysql.connector
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 80.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp38-cp38-linux_x86_64.whl size=247965 sha256=ce40173edf7ac8d0d3a720d15a4eecb919077bd5862e64afbac47be1d407663e
#   Stored in directory: /root/.cache/pip/wheels/57/e4/98/5feafb5c393dd2540e44b064a6f95832990d543e5b4f53ea8f
# Successfully built mysql.connector
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('weather.csv', skiprows = 28, skipfooter = 1)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
col = ['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
       ' Average barometer (in', ' Average windspeed (mph',
       ' Average gustspeed (mph', ' Average direction (°deg',
       ' Rainfall for month (in', 'Rainfall for year (in',
       ' Maximum rain per minute', ' Maximum temperature (°F',
       ' Minimum temperature (°F', ' Maximum humidity (%',
       ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
       ' Maximum windspeed (mph', ' Maximum gust speed (mph',
       ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure']

# %%
df.rename(columns={' Temperature': 'Temperature',
                   ' Average humidity (%': 'Avg Humidity',
                   ' Average dewpoint (°F': 'Avg Dewpoint',
                   ' Average barometer (in': 'Avg Barometer',
                   ' Average windspeed (mph' : 'Avg windspeed',
                   ' Average gustspeed (mph' : 'Avg Gustspeed',
                   ' Average direction (°deg' : 'Avg Direction',
                   ' Rainfall for month (in' : 'Rainfall for month',
                   'Rainfall for year (in': 'Rainfall for year',
                   ' Maximum rain per minute' : 'Max rain per minute',
                   ' Maximum temperature (°F' : 'Max temp',
                   ' Minimum temperature (°F' : 'Min temp',
                   ' Maximum humidity (%' : 'Max humidity',
                   ' Minimum humidity (%' : 'Min humidity',
                   ' Maximum pressure' : 'Max pressure',
                   ' Minimum pressure' : 'Min pressure',
                   ' Maximum windspeed (mph' : 'Max windspeed',
                   ' Maximum gust speed (mph' : 'Max gust speed',
                   ' Maximum heat index (°F' : 'Max heat index',
                   ' Month': 'Month', ' diff_pressure':'Diff pressure'},
          inplace = True)

# %%
df.head()
# Out:
#          Date  Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  \
# 0  2022-01-01         37.8          35.0          12.7           29.7
# 1  2022-01-02         43.2          32.0          14.7           29.5
# 2  2022-01-03         25.7          60.0          12.7           29.7
# 3  2022-01-04          9.3          67.0           0.1           30.4
# 4  2022-01-05         23.5          30.0          -5.3           29.9
#
#    Avg windspeed  Avg Gustspeed  Avg Direction  Rainfall for month  \
# 0           26.4           36.8          274.0                 0.0
# 1           12.8           18.0          240.0                 0.0
# 2            8.3           12.2          290.0                 0.0
# 3            2.9            4.5           47.0                 0.0
# 4           16.7           23.1          265.0                 0.0
#
#    Rainfall for year  ...  Min temp  Max humidity  Min humidity  Max pressure  \
# ...

# %%
df.describe()
# Out:
#        Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  Avg windspeed  \
# count  3900.000000   3900.000000   3900.000000    3900.000000    3900.000000
# mean     44.674231     48.885897     23.133513      29.881462       5.756846
# std      15.329944     17.439054     14.634988       0.250452       4.022305
# min     -12.100000      9.000000    -22.200000      28.200000       0.000000
# 25%      33.700000     36.000000     12.100000      29.700000       2.700000
# 50%      45.150000     47.000000     22.500000      29.900000       4.600000
# 75%      58.000000     61.000000     35.425000      30.000000       8.000000
# max      76.300000     94.000000     55.100000      31.000000      26.400000
#
#        Avg Gustspeed  Avg Direction  Rainfall for month  Rainfall for year  \
# count    3900.000000    3900.000000         3900.000000        3900.000000
# mean       10.009769     216.067949            0.451172           5.488767
# ...

# %%
# Out:
#            Date  Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  \
# 723  2022-02-01        -12.1          63.0         -21.1           30.8
#
#      Avg windspeed  Avg Gustspeed  Avg Direction  Rainfall for month  \
# 723            2.4            4.0          123.0                 0.0
#
#      Rainfall for year  ...  Min temp  Max humidity  Min humidity  \
# 723               0.11  ...     -23.6          70.0          52.0
#
#      Max pressure  Min pressure  Max windspeed  Max gust speed  \
# 723        31.061        30.556           11.5            13.8
#
#      Max heat index  Month        Diff pressure
# 723            -6.1      2  '0.504999999999999'
#
# [1 rows x 22 columns]

# %%
df.dtypes
# Out:
# Date                    object
# Temperature            float64
# Avg Humidity           float64
# Avg Dewpoint           float64
# Avg Barometer          float64
# Avg windspeed          float64
# Avg Gustspeed          float64
# Avg Direction          float64
# Rainfall for month     float64
# Rainfall for year      float64
# Max rain per minute    float64
# Max temp               float64
# Min temp               float64
# Max humidity           float64
# Min humidity           float64
# Max pressure           float64
# Min pressure           float64
# Max windspeed          float64
# Max gust speed         float64
# Max heat index         float64
# Month                    int64
# Diff pressure           object
# Diff                    object
# dtype: object

# %%
df['Date'].value_counts()
# Out:
# 2022-05-22'    12
# 2022-06-12'    12
# 2022-06-18'    12
# 2022-06-17'    12
# 2022-06-16'    12
#                ..
# 2022-12-07'     8
# 2022-12-01'     8
# 2022-12-05'     8
# 2022-02-29'     2
# 2022-01-01      1
# Name: Date, Length: 367, dtype: int64

# %%
df['Date'].unique()

# 13, 14, 15 /03 missing
# December is missing
# Whole January, February of next year is missing
# Out:
# array(['2022-01-01', "2022-01-02'", "2022-01-03'", "2022-01-04'",
#        "2022-01-05'", "2022-01-06'", "2022-01-07'", "2022-01-08'",
#        "2022-01-09'", "2022-01-10'", "2022-01-11'", "2022-01-12'",
#        "2022-01-13'", "2022-01-14'", "2022-01-15'", "2022-01-16'",
#        "2022-01-17'", "2022-01-18'", "2022-01-19'", "2022-01-20'",
#        "2022-01-21'", "2022-01-22'", "2022-01-23'", "2022-01-24'",
#        "2022-01-25'", "2022-01-26'", "2022-01-27'", "2022-01-28'",
#        "2022-01-29'", "2022-01-30'", "2022-01-31'", "2022-02-01'",
#        "2022-02-02'", "2022-02-03'", "2022-02-04'", "2022-02-05'",
#        "2022-02-06'", "2022-02-07'", "2022-02-08'", "2022-02-09'",
#        "2022-02-10'", "2022-02-11'", "2022-02-12'", "2022-02-13'",
#        "2022-02-14'", "2022-02-15'", "2022-02-16'", "2022-02-17'",
#        "2022-02-18'", "2022-02-19'", "2022-02-20'", "2022-02-21'",
#        "2022-02-22'", "2022-02-23'", "2022-02-24'", "2022-02-25'",
# ...

# %%
df.iloc[0:5]['Date']
# Out:
# 0     2022-01-01
# 1    2022-01-02'
# 2    2022-01-03'
# 3    2022-01-04'
# 4    2022-01-05'
# Name: Date, dtype: object

# %%
df.isna().sum() # Checking whether any null data is present or not
# Out:
# Date                   0
# Temperature            0
# Avg Humidity           0
# Avg Dewpoint           0
# Avg Barometer          0
# Avg windspeed          0
# Avg Gustspeed          0
# Avg Direction          0
# Rainfall for month     0
# Rainfall for year      0
# Max rain per minute    0
# Max temp               0
# Min temp               0
# Max humidity           0
# Min humidity           0
# Max pressure           0
# Min pressure           0
# Max windspeed          0
# Max gust speed         0
# Max heat index         0
# Month                  0
# Diff pressure          0
# dtype: int64

# %%
df.nunique() # Unique value in whole data set
# Out:
# Date                    367
# Temperature             656
# Avg Humidity             86
# Avg Dewpoint            637
# Avg Barometer            22
# Avg windspeed           206
# Avg Gustspeed           332
# Avg Direction           329
# Rainfall for month      234
# Rainfall for year       799
# Max rain per minute       1
# Max temp                680
# Min temp                577
# Max humidity             92
# Min humidity             89
# Max pressure           1047
# Min pressure           1062
# Max windspeed            63
# Max gust speed          104
# Max heat index          626
# Month                    12
# Diff pressure          1028
# dtype: int64

# %%
df.head(5)
# Out:
#          Date  Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  \
# 0  2022-01-01         37.8          35.0          12.7           29.7
# 1  2022-01-02         43.2          32.0          14.7           29.5
# 2  2022-01-03         25.7          60.0          12.7           29.7
# 3  2022-01-04          9.3          67.0           0.1           30.4
# 4  2022-01-05         23.5          30.0          -5.3           29.9
#
#    Avg windspeed  Avg Gustspeed  Avg Direction  Rainfall for month  \
# 0           26.4           36.8          274.0                 0.0
# 1           12.8           18.0          240.0                 0.0
# 2            8.3           12.2          290.0                 0.0
# 3            2.9            4.5           47.0                 0.0
# 4           16.7           23.1          265.0                 0.0
#
#    Rainfall for year  ...  Min temp  Max humidity  Min humidity  Max pressure  \
# ...

# %%
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
df.drop_duplicates('Date', keep='first')
# Out:
#             Date  Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  \
# 0     2022-01-01         37.8          35.0          12.7           29.7
# 1     2022-01-02         43.2          32.0          14.7           29.5
# 2     2022-01-03         25.7          60.0          12.7           29.7
# 3     2022-01-04          9.3          67.0           0.1           30.4
# 4     2022-01-05         23.5          30.0          -5.3           29.9
# ...          ...          ...           ...           ...            ...
# 688   2022-12-28         31.7          28.0           1.1           29.9
# 689   2022-12-29         35.5          37.0          10.5           29.2
# 690   2022-12-30         17.5          71.0           9.3           29.4
# 691   2022-12-31          1.5          53.0         -12.5           30.0
# 1248  2022-12-01         46.3          35.0          19.6           29.8
#
#       Avg windspeed  Avg Gustspeed  Avg Direction  Rainfall for month  \
# ...

# %%
df.head()
# Out:
#          Date  Temperature  Avg Humidity  Avg Dewpoint  Avg Barometer  \
# 0  2022-01-01         37.8          35.0          12.7           29.7
# 1  2022-01-02         43.2          32.0          14.7           29.5
# 2  2022-01-03         25.7          60.0          12.7           29.7
# 3  2022-01-04          9.3          67.0           0.1           30.4
# 4  2022-01-05         23.5          30.0          -5.3           29.9
#
#    Avg windspeed  Avg Gustspeed  Avg Direction  Rainfall for month  \
# 0           26.4           36.8          274.0                 0.0
# 1           12.8           18.0          240.0                 0.0
# 2            8.3           12.2          290.0                 0.0
# 3            2.9            4.5           47.0                 0.0
# 4           16.7           23.1          265.0                 0.0
#
#    Rainfall for year  ...  Min temp  Max humidity  Min humidity  Max pressure  \
# ...

# %%
df.to_csv('WEATHER_2.csv', index = False)
